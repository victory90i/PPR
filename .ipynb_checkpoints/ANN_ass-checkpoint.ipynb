# %%
#importing packages
import json
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import (classification_report, confusion_matrix, roc_auc_score, roc_curve)
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df=pd.read_csv('malaria_train.csv')
test_df=pd.read_csv('malaria_test.csv')
val_df=pd.read_csv('malaria_val.csv')

X_train=train_df.drop(columns=['Malaria_Positive']).values.astype(np.float32)
y_train = train_df['Malaria_Positive'].values.astype(np.float32)

X_val=val_df.drop(columns=['Malaria_Positive']).values.astype(np.float32)
y_val=val_df['Malaria_Positive'].values.astype(np.float32)


X_test=test_df.drop(columns=['Malaria_Positive']).values.astype(np.float32)
y_test=test_df['Malaria_Positive'].values.astype(np.float32)

print(f"Train: {X_train.shape}")
print(f"Test: {X_test.shape}")
print(f"Val: {X_val.shape}")
print(f"num of features: {X_train.shape[1]}")
# Out:
# Train: (560, 15)
# Test: (120, 15)
# Val: (120, 15)
# num of features: 15

# %%
import json
import numpy as np

with open("malaria_train.json") as f:
    metadata = json.load(f)

# metadata is a list of records
records = metadata

# Get feature columns, excluding the target
feature_cols = [
    key for key in records[0].keys()
    if key != "Malaria_Positive"
]

# Convert feature values into NumPy arrays
X = np.array(
    [[record[col] for col in feature_cols] for record in records],
    dtype=np.float32
)

# Get target values
y = np.array(
    [record["Malaria_Positive"] for record in records],
    dtype=np.float32
)

print(f"Loaded {len(feature_cols)} features")
print("Feature columns:", feature_cols)
print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# Loaded 15 features
# Feature columns: ['Age', 'Fever_Temp', 'Chills', 'Headache_Severity', 'Vomiting', 'Diarrhea', 'Muscle_Pain', 'Fatigue_Level', 'Sweating', 'Nausea', 'High_Fever', 'Fever_x_Chills', 'Severe_Headache', 'Symptom_Count', 'Vulnerable_Age']
# X shape: (560, 15)
# y shape: (560,)

# %%
def build_ann(n_features):
    inputs = keras.Input(shape=(n_features,), name='features')

    #block1
    x=keras.layers.Dense(128, kernel_regularizer=keras.regularizers.l2(1e-4))(inputs)
    x=keras.layers.BatchNormalization()(x)
    x=keras.layers.Activation('relu')(x)
    x=keras.layers.Dropout(0.3)(x)


    #block 2
    x=keras.layers.Dense(64, kernel_regularizer=keras.regularizers.l2(1e-4))(x)
    x=keras.layers.BatchNormalization()(x)
    x=keras.layers.Activation('relu')(x)
    x=keras.layers.Dropout(0.3)(x)

     #block 3
    x=keras.layers.Dense(32)(x)
    x=keras.layers.Activation('relu')(x)
    x=keras.layers.Dropout(0.2)(x)

    outputs = keras.layers.Dense(1, activation='sigmoid', name='prob')(x)

    return keras.Model(inputs, outputs, name='MalariaANN')
    
model = build_ann(X_train.shape[1])
model.summary()
# Out:
# Model: "MalariaANN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ features (InputLayer)                │ (None, 15)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ prob (Dense)                         │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,185 (51.50 KB)
#  Trainable params: 12,801 (50.00 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model.compile(
    optimizer = keras.optimizers.Adam(learning_rate=5e-4),
    loss='binary_crossentropy',
    metrics=[
        'accuracy',
        keras.metrics.AUC(name='auc'),
        keras.metrics.Precision(name='precision'),
        keras.metrics.Recall(name='recall'),
    ]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
callbacks=[
    keras.callbacks.EarlyStopping(
        monitor='val_auc', patience=15,
        restore_best_weights=True, mode='max', verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_auc', factor=0.5, patience=10,
        min_lr=1e-6, mode='max', verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        'best_malaria.keras', monitor='val_auc',
        save_best_only=True, mode='max', verbose=0
    ),
]

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9946 - auc: 0.9999 - loss: 0.0293 - precision: 0.9957 - recall: 0.9914 - val_accuracy: 0.9750 - val_auc: 0.9986 - val_loss: 0.0590 - val_precision: 0.9608 - val_recall: 0.9800 - learning_rate: 1.2500e-04
# Epoch 45/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9946 - auc: 0.9993 - loss: 0.0394 - precision: 0.9957 - recall: 0.9914 - val_accuracy: 0.9750 - val_auc: 0.9986 - val_loss: 0.0591 - val_precision: 0.9608 - val_recall: 0.9800 - learning_rate: 1.2500e-04
# Epoch 46/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9946 - auc: 1.0000 - loss: 0.0260 - precision: 0.9957 - recall: 0.9914 - val_accuracy: 0.9750 - val_auc: 0.9986 - val_loss: 0.0594 - val_precision: 0.9608 - val_recall: 0.9800 - learning_rate: 1.2500e-04
# Epoch 47/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9911 - auc: 0.9999 - loss: 0.0319 - precision: 0.9872 - recall: 0.9914 - val_accuracy: 0.9750 - val_auc: 0.9986 - val_loss: 0.0594 - val_precision: 0.9608 - val_recall: 0.9800 - learning_rate: 1.2500e-04
# Epoch 48/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9893 - auc: 0.9998 - loss: 0.0358 - precision: 0.9913 - recall: 0.9828 - val_accuracy: 0.9750 - val_auc: 0.9986 - val_loss: 0.0592 - val_precision: 0.9608 - val_recall: 0.9800 - learning_rate: 1.2500e-04
# Epoch 49/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9929 - auc: 0.9998 - loss: 0.0333 - precision: 0.9872 - recall: 0.9957 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0595 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 50/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9893 - auc: 0.9999 - loss: 0.0346 - precision: 0.9830 - recall: 0.9914 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0599 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 51/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9946 - auc: 0.9998 - loss: 0.0300 - precision: 1.0000 - recall: 0.9871 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0596 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 52/300
# 15/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0305 - precision: 0.9948 - recall: 1.0000
# Epoch 52: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9964 - auc: 1.0000 - loss: 0.0286 - precision: 0.9915 - recall: 1.0000 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0600 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 1.2500e-04
# Epoch 53/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9893 - auc: 0.9998 - loss: 0.0329 - precision: 0.9913 - recall: 0.9828 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0600 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 6.2500e-05
# Epoch 54/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9911 - auc: 0.9999 - loss: 0.0314 - precision: 0.9914 - recall: 0.9871 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0597 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 6.2500e-05
# Epoch 55/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9982 - auc: 1.0000 - loss: 0.0244 - precision: 1.0000 - recall: 0.9957 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0596 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 6.2500e-05
# Epoch 56/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9911 - auc: 0.9997 - loss: 0.0351 - precision: 0.9957 - recall: 0.9828 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0595 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 6.2500e-05
# Epoch 57/300
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9946 - auc: 0.9999 - loss: 0.0290 - precision: 0.9915 - recall: 0.9957 - val_accuracy: 0.9667 - val_auc: 0.9986 - val_loss: 0.0596 - val_precision: 0.9600 - val_recall: 0.9600 - learning_rate: 6.2500e-05
# Epoch 57: early stopping
# Restoring model weights from the end of the best epoch: 32.
#
# Epochs run:  57
# Best val AUC:  0.9989

# %%
test_loss, test_accuracy, test_auc, test_precision, test_recall = model.evaluate(
    X_test,
    y_test,
    verbose=1
)

print("Test Accuracy:", test_accuracy)
print("Test AUC:", test_auc)
print("Test Precision:", test_precision)
print("Test Recall:", test_recall)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9917 - auc: 1.0000 - loss: 0.0280 - precision: 1.0000 - recall: 0.9800
# Test Accuracy: 0.9916666746139526
# Test AUC: 1.0
# Test Precision: 1.0
# Test Recall: 0.9800000190734863

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].plot(history.history['loss'], label='Train')
axes[0].plot(history.history['val_loss'], label='Validation')
axes[0].set_title('Loss')
axes[0].set_xlabel('Epoch')
axes[0].legend()

axes[1].plot(history.history['accuracy'], label='Train')
axes[1].plot(history.history['val_accuracy'], label='Validation')
axes[1].set_title('Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].legend()

axes[2].plot(history.history['auc'], label='Train')
axes[2].plot(history.history['val_auc'], label='validation')
axes[2].set_xlabel('Epoch')
axes[2].set_title('AUC')
axes[2].legend()

plt.suptitle('Training History', fontsize=13)
plt.tight_layout()
plt.savefig('training_history.png' , dpi=150, bbox_inches='tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
print(history.history.keys())
# Out:
# dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall', 'val_accuracy', 'val_auc', 'val_loss', 'val_precision', 'val_recall', 'learning_rate'])

# %%
model.load_weights('best_malaria.keras')
test_results=model.evaluate(X_test, y_test, verbose=0)
for name, value in zip(model.metrics_names, test_results):
    print (f"{name:<12}: {value:.4f}")
# Out:
# loss        : 0.0280
# compile_metrics: 0.9917

# %%
y_prob = model.predict(X_test, verbose=0).flatten()
auc_score = roc_auc_score(y_test, y_prob)

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
plt.figure(figsize = (5,5))
plt.plot(fpr,tpr, color='crimson', label=f"ROC curve (AUC = {auc_score:.3f})")
plt.plot([0,1], [0,1], color = 'gray', linestyle='--', label='random guess')
plt.xlabel("False positive rate")
plt.ylabel("true positive rate")
plt.title("ROC curve")
plt.legend()
plt.tight_layout()
plt.savefig("roc_curve.png", dpi=150, bbox_inches="tight")
plt.show()

print(f"ROC-AUC : {auc_score:.4f}")
# Out:
# ROC-AUC : 1.0000

# %%
results = model.evaluate(X_test, y_test, verbose=1)

print("Test results:")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9917 - auc: 1.0000 - loss: 0.0280 - precision: 1.0000 - recall: 0.9800
# Test results:
# loss: 0.0280
# compile_metrics: 0.9917

# %%
from sklearn.metrics import confusion_matrix

y_prob = model.predict(X_test)
y_pred = (y_prob >= 0.5).astype(int).ravel()

cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# [[70  0]
#  [ 1 49]]

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)

print("Training positives:", np.sum(y_train == 1))
print("Training negatives:", np.sum(y_train == 0))

print("Test positives:", np.sum(y_test == 1))
print("Test negatives:", np.sum(y_test == 0))
# print("x_features",X)
# Out:
# X_train shape: (560, 15)
# X_test shape: (120, 15)
# Training positives: 233
# Training negatives: 327
# Test positives: 50
# Test negatives: 70

# %%
y_pred = (y_prob >= 0.5).astype(int)
import seaborn as sns
print(classification_report(y_test, y_pred, target_names=['NO malaria', 'malaria']))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(4.5, 4))
sns.heatmap(cm, annot=True, fmt='d' , cmap='Blues',
            xticklabels=['no_malaria', 'malaria'],
            yticklabels=['no_malaria', 'malaria'])
plt.ylabel('Actual')
plt.xlabel('predicted')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#   NO malaria       0.99      1.00      0.99        70
#      malaria       1.00      0.98      0.99        50
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
import numpy as np

feature_cols=[
    'Age',
    'Fever_Temp1',
    'Chills1',
    'Headache_Severity',
    'Vomiting',
   ' Diarrhea',
    'Muscle_Pain',
    'Fatigue_Level',
    'Sweating',
    'Nausea',
    'High_Fever',
    'Fever_x_Chills',
    'Severe_Headache',
    'Symptom_Count',
    'Vulnerable_Age'
]

def predict_malaria(patient, model):
    patient = pateient.copy()
