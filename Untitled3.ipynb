# %% [markdown]
#   #  1.load data

# %%
from sklearn.datasets import fetch_california_housing
import numpy as np
housing=fetch_california_housing(as_frame=True)
x=housing.data.values.astype(np.float32)
y=housing.target.values.astype(np.float32)
print(f"features:{housing.feature_names}")
print(f"shape: x={x.shape} | y={y.shape}")
print(f"Target_range:{y.min():.2f} - {y.max():.2f} ($100k)")
# Out:
# features:['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# shape: x=(20640, 8) | y=(20640,)
# Target_range:0.15 - 5.00 ($100k)

# %% [markdown]
# # 2.0 preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
X_temp, X_test, y_temp, y_test = train_test_split(
   x,y, test_size=0.15, random_state=42
)
X_train, X_val, y_train, y_val=train_test_split(
    X_temp, y_temp, test_size=0.15, random_state=42
)


scaler=StandardScaler()
X_train= scaler.fit_transform(X_train)
X_val=scaler.transform(X_val)
X_test=scaler.transform(X_test)
print(f"\nTrain:{X_train.shape[0]} | val: {X_val.shape[0]} | Test: {X_test.shape[0]}")
# Out:
# Train:14912 | val: 2632 | Test: 3096

# %%
def build_house_model(input_dim):
    inputs = keras.Input(shape=(input_dim,), name='features')

    x=keras.layers.Dense(256)(inputs)
    x=keras.layers.BatchNormalization()(x)
    x=keras.layers.Activation('relu')(x)
    x=keras.layers.Dropout(0.2)(x)


    x=keras.layers.Dense(128)(x)
    x=keras.layers.BatchNormalization()(x)
    x=keras.layers.Activation('relu')(x)
    x=keras.layers.Dropout(0.2)(x)


    x=keras.layers.Dense(64)(inputs)
    x=keras.layers.BatchNormalization()(x)
    x=keras.layers.Activation('relu')(x)
    x=keras.layers.Dropout(0.1)(x)


    outputs = keras.layers.Dense(1, name='price_output')(x)
    return keras.Model(inputs, outputs, name='HousePriceANN')

# %%
model= build_house_model(input_dim=8)
model.summary()
# Out:
# Model: "HousePriceANN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ features (InputLayer)                │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 64)                  │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_8 (Activation)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ price_output (Dense)                 │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 897 (3.50 KB)
#  Trainable params: 769 (3.00 KB)
#  Non-trainable params: 128 (512.00 B)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss='mse',
    metrics=['mae']
)

# %%
callbacks= [
    keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=15,
        restore_best_weights=True, verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=7,
        min_lr=1e-6, verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        'best_house_model.keras', monitor='val_loss',
        save_best_only=True, verbose=0
    )
]

# %%
history = model.fit(
    X_train, y_train,epochs=200,batch_size=256,
    validation_data=(X_val, y_val),
    callbacks=callbacks, verbose=1
)
# Out:
# Epoch 1/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 4.5374 - mae: 1.6601 - val_loss: 3.0772 - val_mae: 1.3847 - learning_rate: 0.0010
# Epoch 2/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1401 - mae: 0.7743 - val_loss: 1.5647 - val_mae: 0.9228 - learning_rate: 0.0010
# Epoch 3/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8237 - mae: 0.6558 - val_loss: 1.1275 - val_mae: 0.7636 - learning_rate: 0.0010
# Epoch 4/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7275 - mae: 0.6210 - val_loss: 0.8935 - val_mae: 0.6703 - learning_rate: 0.0010
# Epoch 5/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6788 - mae: 0.5991 - val_loss: 0.7596 - val_mae: 0.6084 - learning_rate: 0.0010
# Epoch 6/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6373 - mae: 0.5863 - val_loss: 0.6953 - val_mae: 0.5699 - learning_rate: 0.0010
# Epoch 7/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6192 - mae: 0.5753 - val_loss: 0.6463 - val_mae: 0.5448 - learning_rate: 0.0010
# Epoch 8/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6016 - mae: 0.5642 - val_loss: 0.5999 - val_mae: 0.5253 - learning_rate: 0.0010
# Epoch 9/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5841 - mae: 0.5600 - val_loss: 0.5890 - val_mae: 0.5142 - learning_rate: 0.0010
# Epoch 10/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5731 - mae: 0.5533 - val_loss: 0.6014 - val_mae: 0.5101 - learning_rate: 0.0010
# Epoch 11/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5505 - mae: 0.5442 - val_loss: 0.5915 - val_mae: 0.5052 - learning_rate: 0.0010
# Epoch 12/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5535 - mae: 0.5394 - val_loss: 0.5731 - val_mae: 0.4998 - learning_rate: 0.0010
# Epoch 13/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5444 - mae: 0.5357 - val_loss: 0.5466 - val_mae: 0.4964 - learning_rate: 0.0010
# Epoch 14/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5363 - mae: 0.5299 - val_loss: 0.5428 - val_mae: 0.4942 - learning_rate: 0.0010
# Epoch 15/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5301 - mae: 0.5248 - val_loss: 0.5294 - val_mae: 0.4926 - learning_rate: 0.0010
# Epoch 16/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5215 - mae: 0.5198 - val_loss: 0.5408 - val_mae: 0.4927 - learning_rate: 0.0010
# Epoch 17/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5170 - mae: 0.5191 - val_loss: 0.5433 - val_mae: 0.4911 - learning_rate: 0.0010
# Epoch 18/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4931 - mae: 0.5078 - val_loss: 0.5145 - val_mae: 0.4858 - learning_rate: 0.0010
# Epoch 19/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4919 - mae: 0.5073 - val_loss: 0.5285 - val_mae: 0.4864 - learning_rate: 0.0010
# Epoch 20/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4966 - mae: 0.5084 - val_loss: 0.5260 - val_mae: 0.4856 - learning_rate: 0.0010
# Epoch 21/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4835 - mae: 0.4990 - val_loss: 0.5131 - val_mae: 0.4830 - learning_rate: 0.0010
# Epoch 22/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4715 - mae: 0.4954 - val_loss: 0.5059 - val_mae: 0.4817 - learning_rate: 0.0010
# Epoch 23/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4623 - mae: 0.4898 - val_loss: 0.5073 - val_mae: 0.4798 - learning_rate: 0.0010
# Epoch 24/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4688 - mae: 0.4908 - val_loss: 0.5161 - val_mae: 0.4810 - learning_rate: 0.0010
# Epoch 25/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4657 - mae: 0.4911 - val_loss: 0.5021 - val_mae: 0.4768 - learning_rate: 0.0010
# Epoch 26/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4628 - mae: 0.4875 - val_loss: 0.5108 - val_mae: 0.4821 - learning_rate: 0.0010
# Epoch 27/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4586 - mae: 0.4869 - val_loss: 0.5314 - val_mae: 0.4845 - learning_rate: 0.0010
# Epoch 28/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4555 - mae: 0.4821 - val_loss: 0.5118 - val_mae: 0.4813 - learning_rate: 0.0010
# Epoch 29/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4535 - mae: 0.4827 - val_loss: 0.5106 - val_mae: 0.4818 - learning_rate: 0.0010
# Epoch 30/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4601 - mae: 0.4831 - val_loss: 0.5123 - val_mae: 0.4822 - learning_rate: 0.0010
# Epoch 31/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4423 - mae: 0.4770 - val_loss: 0.4813 - val_mae: 0.4740 - learning_rate: 0.0010
# Epoch 32/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4437 - mae: 0.4807 - val_loss: 0.4822 - val_mae: 0.4737 - learning_rate: 0.0010
# Epoch 33/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4414 - mae: 0.4766 - val_loss: 0.4922 - val_mae: 0.4742 - learning_rate: 0.0010
# Epoch 34/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4398 - mae: 0.4743 - val_loss: 0.4999 - val_mae: 0.4748 - learning_rate: 0.0010
# Epoch 35/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4284 - mae: 0.4691 - val_loss: 0.4978 - val_mae: 0.4742 - learning_rate: 0.0010
# Epoch 36/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4305 - mae: 0.4690 - val_loss: 0.5173 - val_mae: 0.4811 - learning_rate: 0.0010
# Epoch 37/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4301 - mae: 0.4684 - val_loss: 0.4993 - val_mae: 0.4759 - learning_rate: 0.0010
# Epoch 38/200
# 56/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4335 - mae: 0.4712
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4330 - mae: 0.4720 - val_loss: 0.4909 - val_mae: 0.4733 - learning_rate: 0.0010
# Epoch 39/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4276 - mae: 0.4653 - val_loss: 0.5011 - val_mae: 0.4772 - learning_rate: 5.0000e-04
# Epoch 40/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4295 - mae: 0.4685 - val_loss: 0.4944 - val_mae: 0.4751 - learning_rate: 5.0000e-04
# Epoch 41/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4189 - mae: 0.4598 - val_loss: 0.4765 - val_mae: 0.4722 - learning_rate: 5.0000e-04
# Epoch 42/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4247 - mae: 0.4651 - val_loss: 0.4910 - val_mae: 0.4735 - learning_rate: 5.0000e-04
# Epoch 43/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4219 - mae: 0.4649 - val_loss: 0.4877 - val_mae: 0.4732 - learning_rate: 5.0000e-04
# Epoch 44/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4204 - mae: 0.4622 - val_loss: 0.4989 - val_mae: 0.4748 - learning_rate: 5.0000e-04
# Epoch 45/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4258 - mae: 0.4633 - val_loss: 0.4764 - val_mae: 0.4746 - learning_rate: 5.0000e-04
# Epoch 46/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4274 - mae: 0.4675 - val_loss: 0.5024 - val_mae: 0.4760 - learning_rate: 5.0000e-04
# Epoch 47/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4257 - mae: 0.4634 - val_loss: 0.4796 - val_mae: 0.4714 - learning_rate: 5.0000e-04
# Epoch 48/200
# 54/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4115 - mae: 0.4610
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4190 - mae: 0.4628 - val_loss: 0.4838 - val_mae: 0.4710 - learning_rate: 5.0000e-04
# Epoch 49/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4200 - mae: 0.4602 - val_loss: 0.4845 - val_mae: 0.4718 - learning_rate: 2.5000e-04
# Epoch 50/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4212 - mae: 0.4622 - val_loss: 0.4863 - val_mae: 0.4707 - learning_rate: 2.5000e-04
# Epoch 51/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4228 - mae: 0.4629 - val_loss: 0.4931 - val_mae: 0.4725 - learning_rate: 2.5000e-04
# Epoch 52/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4218 - mae: 0.4654 - val_loss: 0.4910 - val_mae: 0.4713 - learning_rate: 2.5000e-04
# Epoch 53/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4186 - mae: 0.4617 - val_loss: 0.4881 - val_mae: 0.4719 - learning_rate: 2.5000e-04
# Epoch 54/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4202 - mae: 0.4634 - val_loss: 0.4807 - val_mae: 0.4690 - learning_rate: 2.5000e-04
# Epoch 55/200
# 51/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4244 - mae: 0.4644
# Epoch 55: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4159 - mae: 0.4587 - val_loss: 0.4906 - val_mae: 0.4719 - learning_rate: 2.5000e-04
# Epoch 56/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4166 - mae: 0.4591 - val_loss: 0.4860 - val_mae: 0.4714 - learning_rate: 1.2500e-04
# Epoch 57/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4143 - mae: 0.4581 - val_loss: 0.4852 - val_mae: 0.4709 - learning_rate: 1.2500e-04
# Epoch 58/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4146 - mae: 0.4586 - val_loss: 0.4794 - val_mae: 0.4695 - learning_rate: 1.2500e-04
# Epoch 59/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4139 - mae: 0.4591 - val_loss: 0.4844 - val_mae: 0.4709 - learning_rate: 1.2500e-04
# Epoch 60/200
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4160 - mae: 0.4604 - val_loss: 0.4809 - val_mae: 0.4698 - learning_rate: 1.2500e-04
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 45.

# %%
from sklearn.metrics import r2_score
results=model.evaluate(X_test, y_test, verbose=0)
print(f"\n===Test Results")
print(f"MSE: {results[0]:.4f}")
print(f"MAE: {results[1]:.4f} (${results[1]*100:.0f}k average error)")
y_pred = model.predict(X_test, verbose=0).flatten()
r2 = r2_score(y_test, y_pred)
print(f"R**2: {r2:.4f} (1.0=perfect)")
# Out:
# ===Test Results
# MSE: 0.4763
# MAE: 0.4767 ($48k average error)
# R**2: 0.6365 (1.0=perfect)

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
axes[0].plot(history.history['loss'], label='Train Loss')
axes[0].plot(history.history['val_loss'], label='Val Loss')
axes[0].set_title('MSE Loss')
axes[0].set_xlabel('Epoch')
axes[0].legend()
axes[1].plot(history.history['mae'], label='Train MAE')
axes[1].plot(history.history['val_mae'], label='Val MAE')
axes[1].set_title('MAE Curves')
axes[1].legend()
axes[2].scatter(y_test,y_pred, alpha=0.3, s=5, color='steelblue')
axes[2].plot([0,5], [0,5], 'r--', label='Perfect')
axes[2].set_xlabel('True ($100k)')
axes[2].set_ylabel('predicted ($100k)')
axes[2].set_title(f'Predicted vs Actual R**2={r2:.3f}')
axes[2].legend()
plt.tight_layout()
plt.savefig('house_price_results.png' , dpi=150)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
