# %%
import numpy as np
print (np.__version__)
print (np.array([1,2,3]))
# Out:
# 2.2.6
# [1 2 3]

# %%
import matplotlib.pyplot as plt

x= [1,2,3,4,5]
y= [1,4,9,16,25]

plt.plot(x,y, color='navy', linewidth=2)
plt.title('my first plot')
plt.xlabel('x')
plt.ylabel('y = x squared')
plt.grid(True)
plt.show()

# %%
# A 1D NumPy array IS a vector 
v = np.array([3, 4])        # 2D vector: x=3, y=4 
u = np.array([1, 2, 3])     # 3D vector 
w = np.array([0.1, -0.5, 2.0, 1.3])  # 4D vector 
  
print(v.shape)    # (2,)  — 2 elements, 1 dimension 
print(u.shape)    # (3,)  — 3 elements, 1 dimension 
print(v.ndim)     # 1 
print(v.dtype)    # int64 (or int32 on Windows)
# Out:
# (2,)
# (3,)
# 1
# int64

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
a = np.array([3, 1]) 
b = np.array([1, 3]) 
c = a + b        # [4, 4] 
  
fig, ax = plt.subplots(figsize=(6, 6)) 
  
# quiver(x_start, y_start, x_length, y_length) 
ax.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, 
          color='navy', label='a = [3,1]') 
ax.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, 
          color='gold', label='b = [1,3]') 
ax.quiver(0, 0, c[0], c[1], angles='xy', scale_units='xy', scale=1, 
          color='red', label='a+b = [4,4]', linestyle='dashed') 
  
ax.set_xlim(-1, 6) 
ax.set_ylim(-1, 6)
ax.axhline(0, color='gray', lw=0.5) 
ax.axvline(0, color='gray', lw=0.5) 
ax.grid(True, alpha=0.3) 
ax.legend(fontsize=12) 
ax.set_title('Vector Addition: a + b = c') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\ai-lab\lib\site-packages\IPython\core\formatters.py:402, in BaseFormatter.__call__(self, obj)
#     400     pass
#     401 else:
# --> 402     return printer(obj)
#     403 # Finally look for special method names
#     404 method = get_real_method(obj, self.print_method)
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\IPython\core\pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\backend_bases.py:2157, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2154     # we do this instead of `self.figure.draw_without_rendering`
#    2155     # so that we can inject the orientation
#    2156     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2157         self.figure.draw(renderer)
#    2158 if bbox_inches:
#    2159     if bbox_inches == "tight":
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\figure.py:3264, in Figure.draw(self, renderer)
#    3261             # ValueError can occur when resizing a window.
#    3263     self.patch.draw(renderer)
# -> 3264     mimage._draw_list_compositing_images(
#    3265         renderer, self, artists, self.suppressComposite)
#    3267     renderer.close_group('figure')
#    3268 finally:
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\axes\_base.py:3226, in _AxesBase.draw(self, renderer)
#    3223 if artists_rasterized:
#    3224     _draw_rasterized(self.get_figure(root=True), artists_rasterized, renderer)
# -> 3226 mimage._draw_list_compositing_images(
#    3227     renderer, self, artists, self.get_figure(root=True).suppressComposite)
#    3229 renderer.close_group('axes')
#    3230 self.stale = False
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\image.py:134, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132 if not_composite or not has_images:
#     133     for a in artists:
# --> 134         a.draw(renderer)
#     135 else:
#     136     # Composite any adjacent images together
#     137     image_group = []
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\legend.py:764, in Legend.draw(self, renderer)
#     761     Shadow(self.legendPatch, **self._shadow_props).draw(renderer)
#     763 self.legendPatch.draw(renderer)
# --> 764 self._legend_box.draw(renderer)
#     766 renderer.close_group('legend')
#     767 self.stale = False
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\artist.py:38, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     renderer.stop_rasterizing()
#      36     renderer._rasterizing = False
# ---> 38 return draw(artist, renderer, *args, **kwargs)
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\offsetbox.py:383, in OffsetBox.draw(self, renderer)
#     381 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     382     c.set_offset((px + ox, py + oy))
# --> 383     c.draw(renderer)
#     384 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     385 self.stale = False
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\artist.py:38, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     renderer.stop_rasterizing()
#      36     renderer._rasterizing = False
# ---> 38 return draw(artist, renderer, *args, **kwargs)
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\offsetbox.py:383, in OffsetBox.draw(self, renderer)
#     381 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     382     c.set_offset((px + ox, py + oy))
# --> 383     c.draw(renderer)
#     384 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     385 self.stale = False
#
#     [... skipping similar frames: _prevent_rasterization.<locals>.draw_wrapper at line 38 (2 times), OffsetBox.draw at line 383 (1 times)]
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\offsetbox.py:383, in OffsetBox.draw(self, renderer)
#     381 for c, (ox, oy) in zip(self.get_visible_children(), offsets):
#     382     c.set_offset((px + ox, py + oy))
# --> 383     c.draw(renderer)
#     384 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     385 self.stale = False
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\artist.py:38, in _prevent_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      35     renderer.stop_rasterizing()
#      36     renderer._rasterizing = False
# ---> 38 return draw(artist, renderer, *args, **kwargs)
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\offsetbox.py:703, in DrawingArea.draw(self, renderer)
#     701     if self._clip_children and not (c.clipbox or c._clippath):
#     702         c.set_clip_path(tpath)
# --> 703     c.draw(renderer)
#     705 _bbox_artist(self, renderer, fill=False, props=dict(pad=0.))
#     706 self.stale = False
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\patches.py:642, in Patch.draw(self, renderer)
#     640 tpath = transform.transform_path_non_affine(path)
#     641 affine = transform.get_affine()
# --> 642 self._draw_paths_with_artist_properties(
#     643     renderer,
#     644     [(tpath, affine,
#     645       # Work around a bug in the PDF and SVG renderers, which
#     646       # do not draw the hatches if the facecolor is fully
#     647       # transparent, but do if it is None.
#     648       self._facecolor if self._facecolor[3] else None)])
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\patches.py:603, in Patch._draw_paths_with_artist_properties(self, renderer, draw_path_args_list)
#     601     lw = 0
#     602 gc.set_linewidth(lw)
# --> 603 gc.set_dashes(*self._dash_pattern)
#     604 gc.set_capstyle(self._capstyle)
#     605 gc.set_joinstyle(self._joinstyle)
#
# File ~\anaconda3\envs\ai-lab\lib\site-packages\matplotlib\backend_bases.py:879, in GraphicsContextBase.set_dashes(self, dash_offset, dash_list)
#     876         raise ValueError(
#     877             "All values in the dash list must be non-negative")
#     878     if dl.size and not np.any(dl > 0.0):
# --> 879         raise ValueError(
#     880             'At least one value in the dash list must be positive')
#     881 self._dashes = dash_offset, dash_list
#
# ValueError: At least one value in the dash list must be positive

# %%
R = np.random.rand(3, 3) 
  
# Random values (standard normal: mean=0, std=1) 
N = np.random.randn(3, 3)
print (R)
print (N)
# Out:
# [[0.79143419 0.19539693 0.81728385]
#  [0.70365761 0.03430924 0.23036792]
#  [0.27555438 0.36987134 0.58315703]]
# [[ 1.15383937 -0.82531898 -0.43654153]
#  [ 0.48580362  1.68453868  0.67562145]
#  [ 1.06970081 -0.71497986 -0.11529566]]

# %%
import numpy as np
import matplotlib.pyplot as plt
M=np.random.rand(5,5)

plt.figure(figsize=(6,5))
plt.imshow(M, cmap='Blues')
plt.colorbar()
plt.title('Matrix as a heatmap')

for i in range(5):
    for j in range(5):
        plt.text(j,i,f'{M[i,j]: .2f}',
                 ha='center', va='center', fontsize=9)
plt.show()

# %%
A = np.random.randn(2, 3) 
B = np.random.randn(3,5)
c=A@B

# %%
import numpy as np 
  
# A 2x2 matrix transforms 2D vectors 
# This matrix SCALES x by 2 and y by 3 
A = np.array([[2, 0], 
              [0, 3]]) 
  
v = np.array([1, 1])    # Original vector 
v_transformed = A @ v   # Apply the transformation 
print(v_transformed)    # [2 3] — x doubled, y tripled
# Out:
# [2 3]

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
def plot_transformation(A, title=''): 
    # Create a grid of points 
    xs = np.linspace(-2, 2, 10) 
    ys = np.linspace(-2, 2, 10) 
    points = [] 
    for x in xs: 
        for y in ys: 
            points.append([x, y]) 
    points = np.array(points).T   # shape (2, N) 
  
    # Apply transfomation
    transformed = A @ points 
  
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5)) 
  
    ax1.scatter(points[0], points[1], color='navy', s=20) 
    ax1.set_title('Before Transformation') 
    ax1.set_xlim(-5, 5); ax1.set_ylim(-5, 5) 
    ax1.axhline(0, color='gray', lw=0.5) 
    ax1.axvline(0, color='gray', lw=0.5) 
    ax1.grid(True, alpha=0.3) 
    ax1.set_aspect('equal') 
  
    ax2.scatter(transformed[0], transformed[1], color='crimson', s=20) 
    ax2.set_title(f'After: {title}') 
    ax2.set_xlim(-5, 5); ax2.set_ylim(-5, 5) 
    ax2.axhline(0, color='gray', lw=0.5) 
    ax2.axvline(0, color='gray', lw=0.5) 
    ax2.grid(True, alpha=0.3) 
    ax2.set_aspect('equal') 
  
    plt.tight_layout() 
    plt.show() 
  
# Scale x by 2, y by 0.5 
A = np.array([[2, 0], [0, 0.5]]) 
plot_transformation(A, 'Scale') 
  
# Rotation by 45 degrees 
theta = np.pi / 4 
R = np.array([[np.cos(theta), -np.sin(theta)], 
              [np.sin(theta),  np.cos(theta)]]) 
plot_transformation(R, 'Rotation 45°')

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
def rotation_matrix(angle_degrees): 
    theta = np.radians(angle_degrees)  # convert degrees to radians 
    return np.array([[np.cos(theta), -np.sin(theta)], 
                     [np.sin(theta),  np.cos(theta)]]) 
  
v = np.array([1, 0])   # Vector pointing right 
  
fig, ax = plt.subplots(figsize=(6, 6)) 
  
colors = ['navy', 'blue', 'dodgerblue', 'gold', 'orange'] 
for i, angle in enumerate([0, 45, 90, 135, 180]): 
    R = rotation_matrix(angle) 
    rotated = R @ v 
    ax.quiver(0, 0, rotated[0], rotated[1], 
              angles='xy', scale_units='xy', scale=1, 
              color=colors[i], label=f'{angle}°') 
  
ax.set_xlim(-1.5, 1.5) 
ax.set_ylim(-1.5, 1.5) 
ax.set_aspect('equal') 
ax.legend() 
ax.grid(True, alpha=0.3) 
ax.set_title('Rotating a vector by different angles') 
plt.show()

# %%
import numpy as np 
  
A = np.array([[3, 1], 
              [0, 2]]) 
  
# np.linalg.eig returns (eigenvalues, eigenvectors) 
# Each COLUMN of the matrix is one eigenvector 
eigenvalues, eigenvectors = np.linalg.eig(A) 
  
print('Eigenvalues:', eigenvalues) 
# Eigenvalues: [3. 2.] 
  
print('Eigenvectors (columns):',) 
print(eigenvectors) 
# [[1.         0.70710678] 
#  [0.         0.70710678]] 
  
# Verify: A @ v = lambda * v for the first eigenpair 
v0 = eigenvectors[:, 0]          # First eigenvector 
lam0 = eigenvalues[0]            # First eigenvalue 
print(np.allclose(A @ v0, lam0 * v))
# Out:
# Eigenvalues: [3. 2.]
# Eigenvectors (columns):
# [[ 1.         -0.70710678]
#  [ 0.          0.70710678]]
# True

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
A = np.array([[3., 1.], 
              [0., 2.]]) 
  
vals, vecs = np.linalg.eig(A) 
  
fig, ax = plt.subplots(figsize=(7, 7)) 
  
# Show effect on random vectors 
np.random.seed(42) 
for _ in range(12): 
    v = np.random.randn(2) 
    v = v / np.linalg.norm(v)     # unit vector 
    Av = A @ v 
    ax.annotate('', xy=Av, xytext=[0,0], 
                arrowprops=dict(arrowstyle='->', color='lightgray')) 
    ax.annotate('', xy=v, xytext=[0,0], 
                arrowprops=dict(arrowstyle='->', color='navy', lw=1.5)) 
  
# Show eigenvectors 
for i, (val, vec) in enumerate(zip(vals, vecs.T)): 
    vec = vec / np.linalg.norm(vec) 
    ax.annotate('', xy=val*vec, xytext=[0,0], 
                arrowprops=dict(arrowstyle='->', color='gold', lw=3)) 
    ax.text(val*vec[0]*1.1, val*vec[1]*1.1, 
            f'λ={val:.1f}', fontsize=12, color='darkgoldenrod') 
  
ax.set_xlim(-4, 4); ax.set_ylim(-4, 4) 
ax.axhline(0, color='k', lw=0.5); ax.axvline(0, color='k', lw=0.5) 
ax.grid(True, alpha=0.3); ax.set_aspect('equal') 
ax.set_title('Eigenvectors (gold) vs random vectors (navy → gray)') 
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# Create a 'fake image' matrix for demonstration 
np.random.seed(0) 
A = np.outer(np.sin(np.linspace(0, np.pi, 100)), 
             np.cos(np.linspace(0, np.pi, 100))) 
A += 0.1 * np.random.randn(100, 100) 
  
U, s, Vt = np.linalg.svd(A) 
  
fig, axes = plt.subplots(1, 4, figsize=(16, 4)) 
  
axes[0].imshow(A, cmap='viridis'); axes[0].set_title('Original') 
  
for ax, k in zip(axes[1:], [1, 5, 20]): 
    # Keep only the top-k singular values 
    A_approx = U[:, :k] @ np.diag(s[:k]) @ Vt[:k, :] 
    ax.imshow(A_approx, cmap='viridis') 
    ax.set_title(f'Rank-{k} approximation') 
    ax.set_xlabel(f'{k}/{len(s)} singular values')
    plt.tight_layout() 
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# Step 1: Create 2D data with a clear 'main direction' 
np.random.seed(42) 
mean = [2, 3] 
cov = [[3, 2], [2, 2]]          # Covariance defines the shape/tilt 
X = np.random.multivariate_normal(mean, cov, 300)  # 300 points, 2D 
  
# Step 2: Center the data (subtract mean) 
X_centered = X - X.mean(axis=0) 
  
# Step 3: Compute SVD on the centered data 
U, s, Vt = np.linalg.svd(X_centered, full_matrices=False) 
  
# Step 4: Principal components are the rows of Vt 
PC1 = Vt[0]   # Direction of most variance 
PC2 = Vt[1]   # Direction of second most variance (perpendicular to PC1) 
  
# Step 5: Project data onto principal components 
X_pca = X_centered @ Vt.T  # shape (300, 2) 
  
# Visualise 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5)) 
  
ax1.scatter(X[:,0], X[:,1], alpha=0.5, color='navy', s=15) 
# Draw principal component directions 
scale = s[0] / np.sqrt(len(X)) * 2 
ax1.quiver(*X.mean(axis=0), *PC1*scale, color='gold', scale=1, 
           scale_units='xy', angles='xy', width=0.01) 
ax1.set_title('Original 2D Data with PC1 (gold)') 
ax1.set_aspect('equal') 
ax1.grid(True, alpha=0.3) 
  
ax2.scatter(X_pca[:,0], X_pca[:,1], alpha=0.5, color='crimson', s=15) 
ax2.set_xlabel('Principal Component 1') 
ax2.set_ylabel('Principal Component 2') 
ax2.set_title('Data in PCA Space') 
ax2.grid(True, alpha=0.3) 
  
# Explained variance 
explained_var = s**2 / np.sum(s**2) 
print(f'PC1 explains: {explained_var[0]*100:.1f}% of variance') 
print(f'PC2 explains: {explained_var[1]*100:.1f}% of variance') 
  
plt.tight_layout() 
plt.show()
# Out:
# PC1 explains: 91.4% of variance
# PC2 explains: 8.6% of variance

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# Example: f(x, y) = x² + y²  (a bowl shape — paraboloid) 
# Gradient: ∇f = [df/dx, df/dy] = [2x, 2y] 
  
def f(x, y): 
    return x**2 + y**2 
  
def gradient_f(x, y): 
    return np.array([2*x, 2*y])    # Analytical gradient 
  
# Numerical gradient approximation (how autograd works conceptually) 
def numerical_gradient(f, x, y, h=1e-5): 
    df_dx = (f(x+h, y) - f(x-h, y)) / (2*h)   # Central difference 
    df_dy = (f(x, y+h) - f(x, y-h)) / (2*h) 
    return np.array([df_dx, df_dy]) 
  
# Test at point (1, 2) 
print('Analytical gradient at (1,2):', gradient_f(1, 2)) 
# [2. 4.] 
print('Numerical gradient at (1,2):', numerical_gradient(f, 1, 2)) 
# [2. 4.]  — same! ✓
# Out:
# Analytical gradient at (1,2): [2 4]
# Numerical gradient at (1,2): [2. 4.]

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# Create a grid of (x, y) values 
x = np.linspace(-3, 3, 20) 
y = np.linspace(-3, 3, 20) 
X, Y = np.meshgrid(x, y)    # meshgrid creates 2D coordinate arrays 
  
# f(x, y) = x^2 + 2*y^2  (an elliptic paraboloid) 
Z = X**2 + 2*Y**2 
  
# Gradients: df/dx = 2x, df/dy = 4y 
U = 2 * X     # x-component of gradient 
V = 4 * Y     # y-component of gradient 
  
fig, axes = plt.subplots(1, 2, figsize=(14, 5)) 
  
# Contour plot (showing the 'height' of f) 
axes[0].contourf(X, Y, Z, levels=20, cmap='Blues') 
axes[0].contour(X, Y, Z, levels=20, colors='navy', alpha=0.3) 
axes[0].set_title('f(x,y) = x² + 2y² — Contour Map') 
axes[0].set_xlabel('x'); axes[0].set_ylabel('y') 
  
# Gradient field (arrows showing direction of steepest ascent) 
axes[1].contourf(X, Y, Z, levels=20, cmap='Blues', alpha=0.4) 
axes[1].quiver(X, Y, U, V, color='crimson', alpha=0.7) 
axes[1].set_title('Gradient Field ∇f — Arrows Point Uphill') 
axes[1].set_xlabel('x'); axes[1].set_ylabel('y') 
  
plt.tight_layout() 
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# Minimise f(x) = (x - 3)^2  (minimum at x = 3) 
def f(x):        return (x - 3)**2 
def df(x):       return 2 * (x - 3)    # Derivative: df/dx 
  
# Gradient descent loop 
x = -2.0          # Starting point (far from minimum) 
lr = 0.1          # Learning rate 
history = [x]     # Record the path 
  
for step in range(30): 
    grad = df(x)          # Compute gradient 
    x = x - lr * grad     # Move OPPOSITE to gradient (downhill) 
    history.append(x) 
    if step < 5:          # Print first few steps 
        print(f'Step {step+1}: x={x:.4f}, f(x)={f(x):.6f}') 
  
# Visualise the descent 
x_range = np.linspace(-3, 7, 200) 
plt.figure(figsize=(10, 5)) 
plt.plot(x_range, f(x_range), 'navy', lw=2, label='f(x) = (x-3)²') 
plt.scatter(history, [f(xi) for xi in history], 
            c=range(len(history)), cmap='autumn_r', 
            s=50, zorder=5, label='Descent path') 
plt.axvline(3, color='green', ls='--', alpha=0.5, label='Minimum at x=3') 
plt.xlabel('x'); plt.ylabel('f(x)') 
plt.title('Gradient Descent Converging to Minimum') 
plt.legend(); plt.grid(True, alpha=0.3) 
plt.show()
# Out:
# Step 1: x=-1.0000, f(x)=16.000000
# Step 2: x=-0.2000, f(x)=10.240000
# Step 3: x=0.4400, f(x)=6.553600
# Step 4: x=0.9520, f(x)=4.194304
# Step 5: x=1.3616, f(x)=2.684355

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# f(w1, w2) = w1^2 + 5*w2^2  (like a loss surface with 2 weights) 
def f(w):  return w[0]**2 + 5*w[1]**2 
def df(w): return np.array([2*w[0], 10*w[1]]) 
  
w = np.array([-2.5, 1.5])  # Starting weights 
lr = 0.08 
path = [w.copy()] 
  
for _ in range(50): 
    w = w - lr * df(w) 
    path.append(w.copy()) 
  
path = np.array(path) 
  
# Plot loss surface and descent path 
w1 = np.linspace(-3, 3, 100) 
w2 = np.linspace(-2, 2, 100) 
W1, W2 = np.meshgrid(w1, w2) 
Z = W1**2 + 5*W2**2 
  
plt.figure(figsize=(8, 6)) 
plt.contourf(W1, W2, Z, levels=30, cmap='Blues', alpha=0.7) 
plt.contour(W1, W2, Z, levels=30, colors='navy', alpha=0.3) 
plt.plot(path[:,0], path[:,1], 'o-', color='gold', 
         markersize=4, lw=2, label='Gradient descent path') 
plt.scatter([0], [0], color='red', s=100, zorder=5, 
            marker='*', label='Minimum (0,0)') 
plt.xlabel('w1 (weight 1)'); plt.ylabel('w2 (weight 2)') 
plt.title('Gradient Descent on a 2D Loss Surface') 
plt.colorbar(label='Loss') 
plt.legend() 
plt.show()
